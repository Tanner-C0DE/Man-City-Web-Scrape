# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://www.transfermarkt.us/manchester-city/spielplandatum/verein/281'

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.select_one('div[class="responsive-table"]')

# %%
#Gathering the current headers in the table. There will be some added later.
headers = [th.text.strip() for th in table.find_all('th')]

# %%
rows = []
competition = []

#Retrieving the data from the html in the webpage.

for tr in table.find_all('tr'):
    row = [td.text.strip() for td in tr.find_all('td')]
    if len(row) == 1: #Using the html to find where the competition names are.
        comp = row
    elif len(row) > 9: #If there is more than just the competition name, there is data we need
        del row[5] #However, this spot contained a blank space where the logo for the team is on the webpage. Not needed.
        competition.append(comp)
    rows.append(row)

competition = [item[0].strip("[]") for item in competition]#Competition names were scraped with brackets around them. Not needed

# %%
#Creating the dataframe
data = []

for row in rows:
    if len(row)>1:
        data.append(row)
        
df = pd.DataFrame(data, columns=headers)
df.insert(0, "Competition", competition) #Inserting the competition list that we created earlier as a new column
df = df[(df['Result'] != '-:-')] #Removing the rows of the games not played yet.

# %%
#Adding a column for outcomes (Win/Draw/Loss)
outcome = []

results = df["Result"]

goals_home = results.str[:3].str.split(":").str[0].tolist()
goals_away = results.str[:3].str.split(":").str[1].tolist()

temp = 0

for n in df["Venue"]:
    if n == "H" and goals_home[temp] > goals_away[temp]:
        outcome.append('W')
        temp = temp + 1
    elif n == "H" and goals_home[temp] < goals_away[temp]: 
        outcome.append('L')
        temp = temp + 1
    elif n == "A" and goals_home[temp] > goals_away[temp]: 
        outcome.append('L')
        temp = temp + 1
    elif n == "A" and goals_home[temp] < goals_away[temp]: 
        outcome.append('W')
        temp = temp + 1
    else:
        outcome.append('D')
        temp = temp + 1

df.insert(10, "Outcome", outcome)
df
# Out:
#               Competition            Matchday          Date      Time Venue  \
# 0        Community Shield               Final   Sat 8/10/24  10:00 AM     A
# 1          Premier League                   1   Sun 8/18/24  11:30 AM     A
# 2          Premier League                   2   Sat 8/24/24  10:00 AM     H
# 3          Premier League                   3   Sat 8/31/24  12:30 PM     A
# 4          Premier League                   4   Sat 9/14/24  10:00 AM     H
# 5   UEFA Champions League         Group Stage   Wed 9/18/24   3:00 PM     H
# 6          Premier League                   5   Sun 9/22/24  11:30 AM     H
# 7                 EFL Cup         Third Round   Tue 9/24/24   2:45 PM     H
# 8          Premier League                   6   Sat 9/28/24   7:30 AM     A
# 9   UEFA Champions League         Group Stage   Tue 10/1/24   3:00 PM     A
# 10         Premier League                   7   Sat 10/5/24  10:00 AM     H
# 11         Premier League                   8  Sun 10/20/24   9:00 AM     A
# 12  UEFA Champions League         Group Stage  Wed 10/23/24   3:00 PM     H
# 13         Premier League                   9  Sat 10/26/24  10:00 AM     H
# 14                EFL Cup        Fourth Round  Wed 10/30/24   4:15 PM     A
# 15         Premier League                  10   Sat 11/2/24  11:00 AM     A
# 16  UEFA Champions League         Group Stage   Tue 11/5/24   3:00 PM     A
# 17         Premier League                  11   Sat 11/9/24  12:30 PM     A
# 18         Premier League                  12  Sat 11/23/24  12:30 PM     H
# 19  UEFA Champions League         Group Stage  Tue 11/26/24   3:00 PM     H
# 20         Premier League                  13   Sun 12/1/24  11:00 AM     A
# 21         Premier League                  14   Wed 12/4/24   2:30 PM     H
# 22         Premier League                  15   Sat 12/7/24  10:00 AM     A
# 23  UEFA Champions League         Group Stage  Wed 12/11/24   3:00 PM     A
# 24         Premier League                  16  Sun 12/15/24  11:30 AM     H
# 25         Premier League                  17  Sat 12/21/24   7:30 AM     A
# 26         Premier League                  18  Thu 12/26/24   7:30 AM     H
# 27         Premier League                  19  Sun 12/29/24   9:30 AM     A
# 28         Premier League                  20    Sat 1/4/25  10:00 AM     H
# 29                 FA Cup         Third Round   Sat 1/11/25  12:45 PM     H
# 30         Premier League                  21   Tue 1/14/25   2:30 PM     A
# 31         Premier League                  22   Sun 1/19/25  11:30 AM     A
# 32  UEFA Champions League         Group Stage   Wed 1/22/25   3:00 PM     A
# 33         Premier League                  23   Sat 1/25/25  12:30 PM     H
# 34  UEFA Champions League         Group Stage   Wed 1/29/25   3:00 PM     H
# 35         Premier League                  24    Sun 2/2/25  11:30 AM     A
# 36                 FA Cup        Fourth Round    Sat 2/8/25   7:15 AM     A
# 37  UEFA Champions League  intermediate stage   Tue 2/11/25   3:00 PM     H
#
#    Ranking               Opponent   System of play Attendance        Result  \
# 0                         Man Utd  4-3-3 Attacking     78.146  7:8  on pens
# 1     (5.)          Chelsea  (4.)          3-4-2-1     39.818           0:2
# 2     (4.)         Ipswich  (18.)          3-4-2-1     55.017           4:1
# 3     (1.)         West Ham  (9.)          3-4-2-1     62.500           1:3
# 4     (1.)        Brentford  (6.)          4-2-3-1     55.017           2:1
# 5                           Inter          3-4-2-1     50.922           0:0
# 6     (1.)          Arsenal  (2.)  4-3-3 Attacking     55.017           2:2
# 7                         Watford          3-4-2-1                      2:1
# 8     (1.)        Newcastle  (6.)          4-2-3-1     52.248           1:1
# 9                 Slo. Bratislava          4-2-3-1     22.500           0:4
# 10    (2.)           Fulham  (6.)          4-1-4-1     55.017           3:2
# 11    (2.)          Wolves  (20.)          4-1-4-1     31.319           1:2
# 12                  Sparta Prague          4-1-4-1     50.116           5:0
# 13    (2.)     Southampton  (19.)          4-1-4-1     55.017           1:0
# 14                      Tottenham          4-1-4-1     60.797           2:1
# 15    (1.)     Bournemouth  (11.)          4-1-4-1     11.231           2:1
# 16                    Sporting CP          4-1-4-1     47.453           4:1
# 17    (2.)         Brighton  (8.)          4-1-4-1     31.715           2:1
# 18    (2.)       Tottenham  (10.)  4-3-3 Attacking     55.097           0:4
# 19                      Feyenoord  4-3-3 Defending     47.011           3:3
# 20    (2.)        Liverpool  (1.)          4-2-3-1     60.248           2:0
# 21    (5.)     Nottm Forest  (6.)          4-2-3-1     51.764           3:0
# 22    (4.)  Crystal Palace  (17.)          4-2-3-1     25.142           2:2
# 23                       Juventus          4-2-3-1     40.890           2:0
# 24    (4.)         Man Utd  (13.)          4-1-4-1     55.097           1:2
# 25    (5.)      Aston Villa  (7.)          4-2-3-1     42.345           2:1
# 26    (7.)         Everton  (15.)          4-1-4-1     55.097           1:1
# 27    (7.)       Leicester  (18.)          4-1-4-1     32.057           0:2
# 28    (6.)        West Ham  (13.)          4-1-4-1     52.737           4:1
# 29                        Salford          3-4-2-1                      8:0
# 30    (6.)       Brentford  (11.)          4-2-3-1     17.048           2:2
# 31    (6.)         Ipswich  (18.)          4-2-3-1     29.841           0:6
# 32                       Paris SG          4-2-3-1     47.818           4:2
# 33    (5.)          Chelsea  (4.)  4-3-3 Attacking     55.097           3:1
# 34                    Club Brugge          4-2-3-1     51.237           3:1
# 35    (4.)          Arsenal  (2.)          4-2-3-1     60.355           5:1
# 36                  Leyton Orient          4-2-3-1                      1:2
# 37                    Real Madrid          4-1-4-1     52.081           2:3
#
#    Outcome
# 0        W
# 1        W
# 2        W
# 3        W
# 4        W
# 5        D
# 6        D
# 7        W
# 8        D
# 9        W
# 10       W
# 11       W
# 12       W
# 13       W
# 14       L
# 15       L
# 16       L
# 17       L
# 18       L
# 19       D
# 20       L
# 21       W
# 22       D
# 23       L
# 24       L
# 25       L
# 26       D
# 27       W
# 28       W
# 29       W
# 30       D
# 31       W
# 32       L
# 33       W
# 34       W
# 35       L
# 36       W
# 37       L

# %%
#Find the winrate for home and away prem games
prem_df = df[df["Competition"] == "Premier League"]
home_games = prem_df[prem_df["Venue"] == "H"]
away_games = prem_df[prem_df["Venue"] == "A"]

# Count total matches
total_matches = len(prem_df)

# Count occurrences of each outcome
win_count = (prem_df['Outcome'] == 'W').sum()
draw_count = (prem_df['Outcome'] == 'D').sum()
loss_count = (prem_df['Outcome'] == 'L').sum()

# Count occurrences of each home outcome
home_win_count = (home_games['Outcome'] == 'W').sum()
home_draw_count = (home_games['Outcome'] == 'D').sum()
home_loss_count = (home_games['Outcome'] == 'L').sum()

# Count occurrences of each away outcome
away_win_count = (away_games['Outcome'] == 'W').sum()
away_draw_count = (away_games['Outcome'] == 'D').sum()
away_loss_count = (away_games['Outcome'] == 'L').sum()

# Calculate rates
win_rate = win_count / total_matches * 100
draw_rate = draw_count / total_matches * 100
loss_rate = loss_count / total_matches * 100

# Calculate home rates
win_rate_h = home_win_count / home_games.shape[0] * 100
draw_rate_h = home_draw_count / home_games.shape[0] * 100
loss_rate_h = home_loss_count / home_games.shape[0] * 100

# Calculate away rates
win_rate_a = away_win_count / away_games.shape[0] * 100
draw_rate_a = away_draw_count / away_games.shape[0] * 100
loss_rate_a = away_loss_count / away_games.shape[0] * 100

# Print results
print(f"Overall Win Rate: {win_rate:.2f}%")
print(f"Overall Draw Rate: {draw_rate:.2f}%")
print(f"Overall Loss Rate: {loss_rate:.2f}%")
print("--------------")
print(f"Home Win Rate: {win_rate_h:.2f}%")
print(f"Home Draw Rate: {draw_rate_h:.2f}%")
print(f"Home Loss Rate: {loss_rate_h:.2f}%")
print("--------------")
print(f"Away Win Rate: {win_rate_a:.2f}%")
print(f"Away Draw Rate: {draw_rate_a:.2f}%")
print(f"Away Loss Rate: {loss_rate_a:.2f}%")
# Out:
# Overall Win Rate: 50.00%
# Overall Draw Rate: 20.83%
# Overall Loss Rate: 29.17%
# --------------
# Home Win Rate: 63.64%
# Home Draw Rate: 18.18%
# Home Loss Rate: 18.18%
# --------------
# Away Win Rate: 38.46%
# Away Draw Rate: 23.08%
# Away Loss Rate: 38.46%

# %%
#I want to find if Man City has a higher winrate for early games(before 12pm) or late games(after 12pm).
early_games = df[df['Time'].str[-2:] == 'AM']
late_games = df[df['Time'].str[-2:] == 'PM']

early_win_count = (early_games['Outcome'] == 'W').sum()
late_win_count = (late_games['Outcome'] == 'W').sum()

early_win_rate = early_win_count / len(early_games) * 100
late_win_rate = late_win_count / len(late_games) * 100

print(f"Early Win Rate: {early_win_rate:.2f}%")
print(f"Late Win Rate: {late_win_rate:.2f}%")
# Out:
# Early Win Rate: 55.00%
# Late Win Rate: 44.44%
